# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.title('student')
plt.plot([1,2,3,4],[2,4,8,6])
plt.plot([1.4,2.4,3.4,5.2],[3,5,8,10])
plt.xlabel('hours')
plt.ylabel('score')
plt.legend(['A student', 'B student'])
plt.show()
